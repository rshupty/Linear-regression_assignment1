# %% [markdown]
# <a href="https://colab.research.google.com/github/rshupty/Linear-regression_assignment1/blob/main/assignment3_shupty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment 3**
#
# **Name : Rubaiyat Shupty**
#
# **ID : 801308801**

# %% [markdown]
# **Problem 1 (i):**

# %%
# Breast Cancer Classification using Logistic Regression

# ---
# Report for Assignment Problem 1 (i)

"""
Problem 1 (25pts):
(i) (7.5+2.5+2.5 points) Use the cancer dataset to build a logistic regression model to classify the type of cancer (Malignant vs. Benign).

This notebook presents the solution using the Breast Cancer dataset from scikit-learn. A logistic regression model is trained using all 30 input features. The dataset is split into training (80%) and testing (20%) sets. The features are standardized before training to ensure optimal model performance. We evaluate the model based on accuracy, precision, and recall, and visualize the confusion matrix.
"""

# ---
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# Load dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Split data into training and testing sets (80/20 split)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train logistic regression model
model = LogisticRegression(max_iter=10000)
model.fit(X_train_scaled, Y_train)

# Predict on the test set
Y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)

print("Model Evaluation Results:")
print("Accuracy:", round(accuracy, 4))
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))

# Export evaluation results to a CSV file
results_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall'],
    'Value': [round(accuracy, 4), round(precision, 4), round(recall, 4)]
})
results_df.to_csv("model_evaluation_results.csv", index=False)
print("Evaluation results exported to 'model_evaluation_results.csv'")

# Plot the confusion matrix
cm = confusion_matrix(Y_test, Y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=data.target_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Model Evaluation Results:
# Accuracy: 0.9825
# Precision: 0.9861
# Recall: 0.9861
# Evaluation results exported to 'model_evaluation_results.csv'

# %% [markdown]
# - **Accuracy** measures the overall correctness of the model.
# - **Precision** indicates how many positively predicted cases were actually positive.
# - **Recall** tells us how well the model captures all positive cases.

# %% [markdown]
# **Problem 1 (ii):**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# Load the dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Train-test split (80/20)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train logistic regression with L2 regularization
model_l2 = LogisticRegression(penalty='l2', C=1.0, max_iter=10000)
model_l2.fit(X_train_scaled, Y_train)

# Make predictions
Y_pred_l2 = model_l2.predict(X_test_scaled)

# Evaluate performance
accuracy_l2 = accuracy_score(Y_test, Y_pred_l2)
precision_l2 = precision_score(Y_test, Y_pred_l2)
recall_l2 = recall_score(Y_test, Y_pred_l2)

# Print metrics
print("L2-Regularized Logistic Regression Results:")
print("Accuracy:", round(accuracy_l2, 4))
print("Precision:", round(precision_l2, 4))
print("Recall:", round(recall_l2, 4))

# Export results to CSV
results_l2_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall'],
    'Value': [round(accuracy_l2, 4), round(precision_l2, 4), round(recall_l2, 4)]
})
results_l2_df.to_csv("l2_regularized_results.csv", index=False)
print("L2 regularized evaluation results exported to 'l2_regularized_results.csv'")

# Plot confusion matrix
cm_l2 = confusion_matrix(Y_test, Y_pred_l2)
disp_l2 = ConfusionMatrixDisplay(confusion_matrix=cm_l2, display_labels=data.target_names)
disp_l2.plot(cmap=plt.cm.Oranges)
plt.title("Confusion Matrix - L2 Regularization")
plt.show()
# Out:
# L2-Regularized Logistic Regression Results:
# Accuracy: 0.9825
# Precision: 0.9861
# Recall: 0.9861
# L2 regularized evaluation results exported to 'l2_regularized_results.csv'

# %% [markdown]
# - Applied L2 regularization (default in LogisticRegression) with penalty='l2' and C=1.0.
# - Reported metrics: Accuracy, Precision, Recall.
# - Exported results to CSV.
# - Visualized the confusion matrix.

# %% [markdown]
# **Problem 2 (i)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# Load the dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Train-test split (80/20)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train a Naive Bayes classifier
model_nb = GaussianNB()
model_nb.fit(X_train_scaled, Y_train)

# Make predictions
Y_pred_nb = model_nb.predict(X_test_scaled)

# Evaluate the model
accuracy_nb = accuracy_score(Y_test, Y_pred_nb)
precision_nb = precision_score(Y_test, Y_pred_nb)
recall_nb = recall_score(Y_test, Y_pred_nb)

# Print the metrics
print("Naive Bayes Classification Results:")
print("Accuracy:", round(accuracy_nb, 4))
print("Precision:", round(precision_nb, 4))
print("Recall:", round(recall_nb, 4))

# Export evaluation results to CSV
results_nb_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall'],
    'Value': [round(accuracy_nb, 4), round(precision_nb, 4), round(recall_nb, 4)]
})
results_nb_df.to_csv("naive_bayes_results.csv", index=False)
print("Evaluation results exported to 'naive_bayes_results.csv'")

# Plot confusion matrix
cm_nb = confusion_matrix(Y_test, Y_pred_nb)
disp_nb = ConfusionMatrixDisplay(confusion_matrix=cm_nb, display_labels=data.target_names)
disp_nb.plot(cmap=plt.cm.Greens)
plt.title("Confusion Matrix - Naive Bayes")
plt.show()
# Out:
# Naive Bayes Classification Results:
# Accuracy: 0.9298
# Precision: 0.9444
# Recall: 0.9444
# Evaluation results exported to 'naive_bayes_results.csv'

# %% [markdown]
# Built a Gaussian Naive Bayes model for binary classification.
# - Evaluated model using accuracy, precision, and recall.
# - Exported evaluation metrics to a CSV file.
# - Displayed confusion matrix for visual understanding.

# %% [markdown]
# **Problem 2 (ii)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Logistic Regression model
lr_model = LogisticRegression(max_iter=10000)
lr_model.fit(X_train_scaled, Y_train)
Y_pred_lr = lr_model.predict(X_test_scaled)

# Naive Bayes model
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, Y_train)
Y_pred_nb = nb_model.predict(X_test_scaled)

# Metrics dictionary
def compute_metrics(Y_true, Y_pred):
    return {
        'Accuracy': accuracy_score(Y_true, Y_pred),
        'Precision': precision_score(Y_true, Y_pred),
        'Recall': recall_score(Y_true, Y_pred),
        'F1 Score': f1_score(Y_true, Y_pred)
    }

metrics_lr = compute_metrics(Y_test, Y_pred_lr)
metrics_nb = compute_metrics(Y_test, Y_pred_nb)

# Convert to DataFrame for plotting
results_df = pd.DataFrame({'Logistic Regression': metrics_lr, 'Naive Bayes': metrics_nb})
results_df = results_df.T  # Transpose for better plotting

# Plotting
results_df.plot(kind='bar', figsize=(10, 6))
plt.title("Model Performance Comparison")
plt.ylabel("Score")
plt.ylim(0, 1.05)
plt.xticks(rotation=0)
plt.legend(title="Metrics")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
#  This bar chart compares Logistic Regression and Naive Bayes classifiers across four key metrics.
# - Logistic Regression tends to perform slightly better in precision and F1 score, indicating better balance between false positives and false negatives.
# - Naive Bayes is slightly faster to train and performs comparably in accuracy.
# - However, it makes stronger assumptions (feature independence), which may lead to slightly lower performance on real-world datasets.
# - Logistic Regression is generally more robust when relationships between features exist.

# %% [markdown]
# **Problem 3 (i)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay

# Load the dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Split into training and testing sets (80/20)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train the SVM classifier
svm_model = SVC(kernel='linear', C=1.0)
svm_model.fit(X_train_scaled, Y_train)

# Make predictions
Y_pred_svm = svm_model.predict(X_test_scaled)

# Evaluate the model
accuracy_svm = accuracy_score(Y_test, Y_pred_svm)
precision_svm = precision_score(Y_test, Y_pred_svm)
recall_svm = recall_score(Y_test, Y_pred_svm)

# Display evaluation metrics
print("SVM Classification Results:")
print("Accuracy:", round(accuracy_svm, 4))
print("Precision:", round(precision_svm, 4))
print("Recall:", round(recall_svm, 4))

# Export results to CSV
results_svm_df = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall'],
    'Value': [round(accuracy_svm, 4), round(precision_svm, 4), round(recall_svm, 4)]
})
results_svm_df.to_csv("svm_results.csv", index=False)
print("Evaluation results exported to 'svm_results.csv'")

# Confusion matrix
cm_svm = confusion_matrix(Y_test, Y_pred_svm)
disp_svm = ConfusionMatrixDisplay(confusion_matrix=cm_svm, display_labels=data.target_names)
disp_svm.plot(cmap=plt.cm.Purples)
plt.title("Confusion Matrix - SVM")
plt.show()

# %% [markdown]
# SVM classifier trained using a linear kernel.
# - Evaluated with accuracy, precision, and recall.
# - Metrics exported to a CSV file.
# - Confusion matrix plotted for performance visualization.

# %% [markdown]
# **Problem 3 (ii)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load the dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Train-test split (80/20)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Logistic Regression
lr_model = LogisticRegression(max_iter=10000)
lr_model.fit(X_train_scaled, Y_train)
Y_pred_lr = lr_model.predict(X_test_scaled)

# Naive Bayes
nb_model = GaussianNB()
nb_model.fit(X_train_scaled, Y_train)
Y_pred_nb = nb_model.predict(X_test_scaled)

# SVM
svm_model = SVC(kernel='linear', C=1.0)
svm_model.fit(X_train_scaled, Y_train)
Y_pred_svm = svm_model.predict(X_test_scaled)

# Function to compute metrics
def compute_metrics(Y_true, Y_pred):
    return {
        'Accuracy': accuracy_score(Y_true, Y_pred),
        'Precision': precision_score(Y_true, Y_pred),
        'Recall': recall_score(Y_true, Y_pred),
        'F1 Score': f1_score(Y_true, Y_pred)
    }

# Calculate metrics for all models
metrics_lr = compute_metrics(Y_test, Y_pred_lr)
metrics_nb = compute_metrics(Y_test, Y_pred_nb)
metrics_svm = compute_metrics(Y_test, Y_pred_svm)

# Prepare DataFrame for plotting
results_df = pd.DataFrame({
    'Logistic Regression': metrics_lr,
    'Naive Bayes': metrics_nb,
    'SVM': metrics_svm
})
results_df = results_df.T  # Transpose for plotting

# Plot
results_df.plot(kind='bar', figsize=(10, 6))
plt.title("Classifier Performance Comparison")
plt.ylabel("Score")
plt.ylim(0, 1.05)
plt.xticks(rotation=0)
plt.legend(title="Metrics")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# This chart visually compares performance metrics of SVM, Logistic Regression, and Naive Bayes.
# - SVM and Logistic Regression show very strong and close performance across all metrics.
# - Naive Bayes is slightly behind, which could be due to its strong independence assumptions that don't always hold.
# - Logistic Regression is interpretable and stable, while SVM is powerful especially for high-dimensional data.
# - These results help in understanding which model to choose based on task requirements like speed, interpretability, and accuracy.

# %% [markdown]
# **Problem 4 **

# %% [markdown]
# PCA was applied for dimensionality reduction before logistic regression.
# - Each value of K (1 to 30) was tested to determine which number of principal components produced the best classification performance.
# - The optimum K was selected based on the highest accuracy.
# - Compared to Problem 1 (full features), PCA can offer similar performance with fewer features, improving efficiency.
# - Performance differences between PCA and non-PCA approaches highlight the impact of feature extraction on model generalization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Load dataset
data = load_breast_cancer()
X = data.data
Y = data.target

# Split data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Evaluate over K components
max_components = X.shape[1]  # Max number of principal components
scores = []

for k in range(1, max_components + 1):
    pca = PCA(n_components=k)
    X_train_pca = pca.fit_transform(X_train_scaled)
    X_test_pca = pca.transform(X_test_scaled)

    model = LogisticRegression(max_iter=10000)
    model.fit(X_train_pca, Y_train)
    Y_pred = model.predict(X_test_pca)

    accuracy = accuracy_score(Y_test, Y_pred)
    precision = precision_score(Y_test, Y_pred)
    recall = recall_score(Y_test, Y_pred)
    f1 = f1_score(Y_test, Y_pred)

    scores.append((k, accuracy, precision, recall, f1))

# Convert to DataFrame
scores_df = pd.DataFrame(scores, columns=['K', 'Accuracy', 'Precision', 'Recall', 'F1'])

# Find best K
best_row = scores_df.loc[scores_df['Accuracy'].idxmax()]
print("Best number of components (K):", int(best_row['K']))
print(best_row)

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(scores_df['K'], scores_df['Accuracy'], label='Accuracy')
plt.plot(scores_df['K'], scores_df['Precision'], label='Precision')
plt.plot(scores_df['K'], scores_df['Recall'], label='Recall')
plt.plot(scores_df['K'], scores_df['F1'], label='F1 Score')
plt.title("Logistic Regression Performance vs PCA Components")
plt.xlabel("Number of PCA Components (K)")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Best number of components (K): 18
# K            18.000000
# Accuracy      0.982456
# Precision     0.986111
# Recall        0.986111
# F1            0.986111
# Name: 17, dtype: float64
